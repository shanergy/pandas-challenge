# %%
# Dependencies
import pandas as pd

# %%
# CSV Files to Load
schools_path = "../../../SMU_DS/02-Homework/04-Pandas/Instructions/PyCitySchools/Resources/schools_complete.csv"
students_path = "../../../SMU_DS/02-Homework/04-Pandas/Instructions/PyCitySchools/Resources/students_complete.csv"

# %%
# Read CSV Files
schools_df = pd.read_csv(schools_path)
students_df = pd.read_csv(students_path)

# %%
# test/show schools_df
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# calculate "Per Student Budget" and place into a new column
schools_df["budget_per_student"] = (schools_df["budget"] / schools_df["size"]).astype(float)
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget  \
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500
#
#    budget_per_student
# 0               655.0
# 1               639.0
# 2               600.0
# 3               652.0
# 4               625.0

# %%
# test/show students_df
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# add two new columns: "passing_reading_flag" and "passing_reading_flag"
students_df["passing_reading_flag"] = [1 if x >= 70 else 0 for x in students_df["reading_score"]]
students_df["passing_math_flag"] = [1 if x >= 70 else 0 for x in students_df["math_score"]]
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  passing_reading_flag  passing_math_flag
# 0             66          79                     0                  1
# 1             94          61                     1                  0
# 2             90          60                     1                  0
# 3             67          58                     0                  0
# 4             97          84                     1                  1

# %%
# Combine Data into one dataset
combinedRaw_df = pd.merge(students_df, schools_df, how="left", on=["school_name", "school_name"])

# %%
# test/show combined df
combinedRaw_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  passing_reading_flag  passing_math_flag  \
# 0             66          79                     0                  1
# 1             94          61                     1                  0
# 2             90          60                     1                  0
# 3             67          58                     0                  0
# 4             97          84                     1                  1
#
#    School ID      type  size   budget  budget_per_student
# 0          0  District  2917  1910635               655.0
# 1          0  District  2917  1910635               655.0
# 2          0  District  2917  1910635               655.0
# 3          0  District  2917  1910635               655.0
# 4          0  District  2917  1910635               655.0

# %%
# create dataset to be used for calculations below
df = combinedRaw_df

# %%
# test/show combined df
df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  passing_reading_flag  passing_math_flag  \
# 0             66          79                     0                  1
# 1             94          61                     1                  0
# 2             90          60                     1                  0
# 3             67          58                     0                  0
# 4             97          84                     1                  1
#
#    School ID      type  size   budget  budget_per_student
# 0          0  District  2917  1910635               655.0
# 1          0  District  2917  1910635               655.0
# 2          0  District  2917  1910635               655.0
# 3          0  District  2917  1910635               655.0
# 4          0  District  2917  1910635               655.0

# %%
# Check to see what the data types are fore ach column:
df.dtypes
# Out:
# Student ID                int64
# student_name             object
# gender                   object
# grade                    object
# school_name              object
# reading_score             int64
# math_score                int64
# passing_reading_flag      int64
# passing_math_flag         int64
# School ID                 int64
# type                     object
# size                      int64
# budget                    int64
# budget_per_student      float64
# dtype: object

# %%
# Check to see what the data looks like in columns with numerical values:
df.describe()
# Out:
#          Student ID  reading_score    math_score  passing_reading_flag  \
# count  39170.000000    39170.00000  39170.000000          39170.000000
# mean   19584.500000       81.87784     78.985371              0.858055
# std    11307.549359       10.23958     12.309968              0.348999
# min        0.000000       63.00000     55.000000              0.000000
# 25%     9792.250000       73.00000     69.000000              1.000000
# 50%    19584.500000       82.00000     79.000000              1.000000
# 75%    29376.750000       91.00000     89.000000              1.000000
# max    39169.000000       99.00000     99.000000              1.000000
#
#        passing_math_flag     School ID          size        budget  \
# count       39170.000000  39170.000000  39170.000000  3.917000e+04
# mean            0.749809      6.978172   3332.957110  2.117241e+06
# std             0.433129      4.444329   1323.914069  8.749987e+05
# min             0.000000      0.000000    427.000000  2.480870e+05
# 25%             0.000000      3.000000   1858.000000  1.081356e+06
# 50%             1.000000      7.000000   2949.000000  1.910635e+06
# 75%             1.000000     11.000000   4635.000000  3.022020e+06
# max             1.000000     14.000000   4976.000000  3.124928e+06
#
#        budget_per_student
# count        39170.000000
# mean           629.293541
# std             25.034815
# min            578.000000
# 25%            625.000000
# 50%            638.000000
# 75%            650.000000
# max            655.000000

# %%
# Check to see if there are any rows with any missing data:
df.count()
# df["school_name"].value_counts()
# Out:
# Student ID              39170
# student_name            39170
# gender                  39170
# grade                   39170
# school_name             39170
# reading_score           39170
# math_score              39170
# passing_reading_flag    39170
# passing_math_flag       39170
# School ID               39170
# type                    39170
# size                    39170
# budget                  39170
# budget_per_student      39170
# dtype: int64

# %%
# Check to count unique/distinct number of values for each column:
df.nunique()
# Out:
# Student ID              39170
# student_name            32715
# gender                      2
# grade                       4
# school_name                15
# reading_score              37
# math_score                 45
# passing_reading_flag        2
# passing_math_flag           2
# School ID                  15
# type                        2
# size                       15
# budget                     15
# budget_per_student         15
# dtype: int64

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate the total number of schools
totalSchools = df["School ID"].nunique()
# totalSchools = len(df["school_name"].unique())
# totalSchools = len(df["School ID"].unique())
totalSchools
# Out:
# 15

# %%
# Calculate the total number of students
totalStudents = df["Student ID"].nunique()
# totalStudents = df["Student ID"].count()
totalStudents
# Out:
# 39170

# %%
# Calculate the total budget
totalBudget = schools_df["budget"].sum()
totalBudget
# Out:
# 24649428

# %%
# Calculate the average math score
avgMathScore = df["math_score"].mean()
avgMathScore
# Out:
# 78.98537145774827

# %%
# Calculate the average reading score
avgReadingScore = df["reading_score"].mean()
avgReadingScore
# Out:
# 81.87784018381414

# %%
# Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
avgOverallPassingRate = (df["math_score"].mean() + df["reading_score"].mean()) / 2
avgOverallPassingRate
# Out:
# 80.43160582078121

# %%
# Calculate the percentage of students with a passing math score (70 or greater)
# df.loc[df["math_score"] >= 70,:]
# len(df.loc[df["math_score"] >= 70,:])
# df["math_score"].count()
# ((df["math_score"] >= 70) == True).value_counts()
# passingMathScore = df["math_score"] >= 70
# passingMathScore.value_counts()


# passingMathScore = ((df["math_score"] >= 70) == True).value_counts()
# passingMathScore = passingMathScore[True]
# passingMathScore

# ((df["math_score"] >= 70) == True).value_counts()[True]

passingMath = (df["math_score"] >= 70).value_counts()[True]
# passingMath
pctPassingMath = passingMath / totalStudents * 100
pctPassingMath
# Out:
# 74.9808526933878

# %%
# Calculate the percentage of students with a passing reading score (70 or greater)
passingReading = (df["reading_score"] >= 70).value_counts()[True]
# passingReading
pctPassingReading = passingReading / totalStudents * 100
pctPassingReading
# Out:
# 85.80546336482001

# %%
# Create a summary DataFrame to hold the above summary results for the district
districtSummary_df = pd.DataFrame({"Total Schools": [totalSchools],
                                   "Total Students": [totalStudents],
                                   "Total Budget": [totalBudget],
                                   "Average Math Score": [avgMathScore],
                                   "Average Reading Score": [avgReadingScore],
                                   "% Passing Math": [pctPassingMath],
                                   "% Passing Reading": [pctPassingReading],
                                   "% Overall Passing Rate": [avgOverallPassingRate]
                                  })
# districtSummary_df

districtSummary_df["Total Students"] = districtSummary_df["Total Students"].astype(int).map("{:,}".format)
districtSummary_df["Total Budget"] = districtSummary_df["Total Budget"].astype(float).map("${:,.2f}".format)

districtSummary_df
# districtSummary_df.transpose()
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               80.431606

# %% [markdown]
# ## School Summary
#
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
# xxxxxxxxxxCreate a summary DataFrame to hold the above summary results for the district ((TESTING))
districtSummary_df2 = pd.DataFrame({"Total Schools": df["School ID"].nunique(),
                                   "Total Students": df["Student ID"].nunique(),
                                   "Total Budget": schools_df["budget"].sum(),
                                   "Average Math Score": df["math_score"].mean(),
                                   "Average Reading Score": df["reading_score"].mean(),
                                   "% Passing Math": (df["math_score"] >= 70).value_counts()[True] / totalStudents * 100,
                                   "% Passing Reading": (df["reading_score"] >= 70).value_counts()[True] / totalStudents * 100,
                                   "% Overall Passing Rate": [(df["math_score"].mean() + df["reading_score"].mean()) / 2]
                                  })
# districtSummary_df2

districtSummary_df2["Total Students"] = districtSummary_df2["Total Students"].astype(int).map("{:,}".format)
districtSummary_df2["Total Budget"] = districtSummary_df2["Total Budget"].astype(float).map("${:,.2f}".format)

districtSummary_df2
# districtSummary_df2.transpose()
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               80.431606

# %%
# Grouping the DataFrame by "School Name"
# assignee_group = eclipse_df.groupby("Assignee")
# schools_group = df.groupby("school_name")

# Count how many of each component Assignees worked on and create DataFrame
# assignee_work = pd.DataFrame(assignee_group["Component"].value_counts())
# assignee_work = pd.DataFrame(assignee_group["Component"].value_counts())
# schoolsSummary_df = pd.DataFrame(schools_group[])
# assignee_work.head()

# schools_group.head()


schools_test = df.loc[:, ["school_name","Student ID","School ID","type","size","budget"]]
schools_test
# Out:
#               school_name  Student ID  School ID      type  size   budget
# 0       Huang High School           0          0  District  2917  1910635
# 1       Huang High School           1          0  District  2917  1910635
# 2       Huang High School           2          0  District  2917  1910635
# 3       Huang High School           3          0  District  2917  1910635
# 4       Huang High School           4          0  District  2917  1910635
# ...                   ...         ...        ...       ...   ...      ...
# 39165  Thomas High School       39165         14   Charter  1635  1043130
# 39166  Thomas High School       39166         14   Charter  1635  1043130
# 39167  Thomas High School       39167         14   Charter  1635  1043130
# 39168  Thomas High School       39168         14   Charter  1635  1043130
# 39169  Thomas High School       39169         14   Charter  1635  1043130
#
# [39170 rows x 6 columns]

# %%
# Using GroupBy in order to separate the data into fields according to "school_name" values
grouped_schools_df = df.groupby(["school_name"])
# grouped_schools_df = df.groupby(["School ID", "school_name", "type", "size", "budget"])
# grouped_schools_df
# print(grouped_schools_df)
grouped_schools_df.sum()
# Out:
#                        Student ID  reading_score  math_score  \
# school_name
# Bailey High School      101303896         403225      383393
# Cabrera High School      31477307         156027      154329
# Figueroa High School     12949059         239335      226223
# Ford High School         99055935         221164      211184
# Griffin High School      19077394         123043      122360
# Hernandez High School    46090440         375131      358238
# Holden High School        9846620          35789       35784
# Huang High School         4252986         236810      223528
# Johnson High School     154327815         385481      366942
# Pena High School         22851829          80851       80654
# Rodriguez High School   112111965         322898      307294
# Shelton High School      11879706         147441      146796
# Thomas High School       62705520         137093      136389
# Wilson High School       33950493         191748      190115
# Wright High School       45243900         151119      150628
#
#                        passing_reading_flag  passing_math_flag  School ID  \
# school_name
# Bailey High School                     4077               3318      34832
# Cabrera High School                    1803               1749      11148
# Figueroa High School                   2381               1946       2949
# Ford High School                       2172               1871      35607
# Griffin High School                    1426               1371       5872
# Hernandez High School                  3748               3094      13905
# Holden High School                      411                395       3416
# Huang High School                      2372               1916          0
# Johnson High School                    3867               3145      57132
# Pena High School                        923                910       8658
# Rodriguez High School                  3208               2654      43989
# Shelton High School                    1688               1653       3522
# Thomas High School                     1591               1525      22890
# Wilson High School                     2204               2143      11415
# Wright High School                     1739               1680      18000
#
#                            size       budget  budget_per_student
# school_name
# Bailey High School     24760576  15549641728           3124928.0
# Cabrera High School     3452164   2009159448           1081356.0
# Figueroa High School    8696601   5557128039           1884411.0
# Ford High School        7502121   4831365924           1763916.0
# Griffin High School     2155024   1346890000            917500.0
# Hernandez High School  21483225  14007062700           3022020.0
# Holden High School       182329    105933149            248087.0
# Huang High School       8508889   5573322295           1910635.0
# Johnson High School    22667121  14733628650           3094650.0
# Pena High School         925444    563595396            585858.0
# Rodriguez High School  15992001  10186904637           2547363.0
# Shelton High School     3101121   1860672600           1056600.0
# Thomas High School      2673225   1705517550           1043130.0
# Wilson High School      5212089   3012587442           1319574.0
# Wright High School      3240000   1888920000           1049400.0

# %%
# Calculate the total number of students per school
# df.groupby(['school_name'])["Student ID"].nunique()
# totalStudentsBySchools = grouped_schools_df["Student ID"].nunique()
# totalStudents = df["Student ID"].count()
# schoolsStudentCounts = df.groupby(["School ID", "school_name", "type", "size", "budget"])["Student ID"].nunique()
# schoolsStudentCounts
# schoolsAvgMathScores = df.groupby(["School ID", "school_name", "type", "size", "budget"])["math_score"].mean()
# schoolsAvgMathScores
# schoolsAvgReadingScores = df.groupby(["School ID", "school_name", "type", "size", "budget"])["reading_score"].mean()
# schoolsAvgReadingScores
# schoolsPassingMath = df.groupby(["School ID", "school_name", "type", "size", "budget"])["passing_math_flag"].sum()
# schoolsPassingMath
# schoolsPassingReading = df.groupby(["School ID", "school_name", "type", "size", "budget"])["passing_reading_flag"].sum()
# schoolsPassingReading

# %%
# Calculate the total number of students per school
# df.groupby(['school_name'])["Student ID"].nunique()
# totalStudentsBySchools = grouped_schools_df["Student ID"].nunique()
# totalStudents = df["Student ID"].count()
schoolsStudentCounts = grouped_schools_df["Student ID"].nunique()
# schoolsStudentCounts
schoolsAvgMathScores = grouped_schools_df["math_score"].mean()
# schoolsAvgMathScores
schoolsAvgReadingScores = grouped_schools_df["reading_score"].mean()
# schoolsAvgReadingScores
schoolsPassingMath = grouped_schools_df["passing_math_flag"].sum()
# schoolsPassingMath
schoolsPassingReading = grouped_schools_df["passing_reading_flag"].sum()
# schoolsPassingReading
schoolsType = grouped_schools_df["type"].unique()
# schoolsType
schoolsTotalBudget = grouped_schools_df["budget"].mean()
# schoolsTotalBudget
schoolsBudgetPerStudent = grouped_schools_df["budget_per_student"].mean()
# schoolsBudgetPerStudent

# %%
# Create a summary DataFrame to hold the above summary results for each school
schoolsSummary_df = pd.DataFrame({"School Type": schoolsType,
                                  "Total Students": schoolsStudentCounts,
                                  "Total School Budget": schoolsTotalBudget,
                                  "Per Student Budget": schoolsBudgetPerStudent,
                                  "Average Math Score": schoolsAvgMathScores,
                                  "Average Reading Score": schoolsAvgReadingScores,
                                  "% Passing Math": schoolsPassingMath / schoolsStudentCounts * 100,
                                  "% Passing Reading": schoolsPassingReading / schoolsStudentCounts * 100,
                                  "% Overall Passing Rate": (schoolsPassingMath + schoolsPassingReading) / schoolsStudentCounts / 2 * 100
                                  })
# schoolsSummary_df

schoolsSummary_df["Total Students"] = schoolsSummary_df["Total Students"].astype(int).map("{:,}".format)
schoolsSummary_df["Total School Budget"] = schoolsSummary_df["Total School Budget"].astype(float).map("${:,.2f}".format)
schoolsSummary_df["Per Student Budget"] = schoolsSummary_df["Per Student Budget"].astype(float).map("${:,.2f}".format)

schoolsSummary_df
# schoolsSummary_df.transpose()
# Out:
#                       School Type Total Students Total School Budget  \
# school_name
# Bailey High School     [District]          4,976       $3,124,928.00
# Cabrera High School     [Charter]          1,858       $1,081,356.00
# Figueroa High School   [District]          2,949       $1,884,411.00
# Ford High School       [District]          2,739       $1,763,916.00
# Griffin High School     [Charter]          1,468         $917,500.00
# Hernandez High School  [District]          4,635       $3,022,020.00
# Holden High School      [Charter]            427         $248,087.00
# Huang High School      [District]          2,917       $1,910,635.00
# Johnson High School    [District]          4,761       $3,094,650.00
# Pena High School        [Charter]            962         $585,858.00
# Rodriguez High School  [District]          3,999       $2,547,363.00
# Shelton High School     [Charter]          1,761       $1,056,600.00
# Thomas High School      [Charter]          1,635       $1,043,130.00
# Wilson High School      [Charter]          2,283       $1,319,574.00
# Wright High School      [Charter]          1,800       $1,049,400.00
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Bailey High School               $628.00           77.048432
# Cabrera High School              $582.00           83.061895
# Figueroa High School             $639.00           76.711767
# Ford High School                 $644.00           77.102592
# Griffin High School              $625.00           83.351499
# Hernandez High School            $652.00           77.289752
# Holden High School               $581.00           83.803279
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Pena High School                 $609.00           83.839917
# Rodriguez High School            $637.00           76.842711
# Shelton High School              $600.00           83.359455
# Thomas High School               $638.00           83.418349
# Wilson High School               $578.00           83.274201
# Wright High School               $583.00           83.682222
#
#                        Average Reading Score  % Passing Math  \
# school_name
# Bailey High School                 81.033963       66.680064
# Cabrera High School                83.975780       94.133477
# Figueroa High School               81.158020       65.988471
# Ford High School                   80.746258       68.309602
# Griffin High School                83.816757       93.392371
# Hernandez High School              80.934412       66.752967
# Holden High School                 83.814988       92.505855
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Pena High School                   84.044699       94.594595
# Rodriguez High School              80.744686       66.366592
# Shelton High School                83.725724       93.867121
# Thomas High School                 83.848930       93.272171
# Wilson High School                 83.989488       93.867718
# Wright High School                 83.955000       93.333333
#
#                        % Passing Reading  % Overall Passing Rate
# school_name
# Bailey High School             81.933280               74.306672
# Cabrera High School            97.039828               95.586652
# Figueroa High School           80.739234               73.363852
# Ford High School               79.299014               73.804308
# Griffin High School            97.138965               95.265668
# Hernandez High School          80.862999               73.807983
# Holden High School             96.252927               94.379391
# Huang High School              81.316421               73.500171
# Johnson High School            81.222432               73.639992
# Pena High School               95.945946               95.270270
# Rodriguez High School          80.220055               73.293323
# Shelton High School            95.854628               94.860875
# Thomas High School             97.308869               95.290520
# Wilson High School             96.539641               95.203679
# Wright High School             96.611111               94.972222

# %%
# schoolsSummary_df = schoolsSummary_df.set_index("school_name")
del schoolsSummary_df.index.name
schoolsSummary_df
# Out:
#                       School Type Total Students Total School Budget  \
# Bailey High School     [District]          4,976       $3,124,928.00
# Cabrera High School     [Charter]          1,858       $1,081,356.00
# Figueroa High School   [District]          2,949       $1,884,411.00
# Ford High School       [District]          2,739       $1,763,916.00
# Griffin High School     [Charter]          1,468         $917,500.00
# Hernandez High School  [District]          4,635       $3,022,020.00
# Holden High School      [Charter]            427         $248,087.00
# Huang High School      [District]          2,917       $1,910,635.00
# Johnson High School    [District]          4,761       $3,094,650.00
# Pena High School        [Charter]            962         $585,858.00
# Rodriguez High School  [District]          3,999       $2,547,363.00
# Shelton High School     [Charter]          1,761       $1,056,600.00
# Thomas High School      [Charter]          1,635       $1,043,130.00
# Wilson High School      [Charter]          2,283       $1,319,574.00
# Wright High School      [Charter]          1,800       $1,049,400.00
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School               $628.00           77.048432
# Cabrera High School              $582.00           83.061895
# Figueroa High School             $639.00           76.711767
# Ford High School                 $644.00           77.102592
# Griffin High School              $625.00           83.351499
# Hernandez High School            $652.00           77.289752
# Holden High School               $581.00           83.803279
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Pena High School                 $609.00           83.839917
# Rodriguez High School            $637.00           76.842711
# Shelton High School              $600.00           83.359455
# Thomas High School               $638.00           83.418349
# Wilson High School               $578.00           83.274201
# Wright High School               $583.00           83.682222
#
#                        Average Reading Score  % Passing Math  \
# Bailey High School                 81.033963       66.680064
# Cabrera High School                83.975780       94.133477
# Figueroa High School               81.158020       65.988471
# Ford High School                   80.746258       68.309602
# Griffin High School                83.816757       93.392371
# Hernandez High School              80.934412       66.752967
# Holden High School                 83.814988       92.505855
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Pena High School                   84.044699       94.594595
# Rodriguez High School              80.744686       66.366592
# Shelton High School                83.725724       93.867121
# Thomas High School                 83.848930       93.272171
# Wilson High School                 83.989488       93.867718
# Wright High School                 83.955000       93.333333
#
#                        % Passing Reading  % Overall Passing Rate
# Bailey High School             81.933280               74.306672
# Cabrera High School            97.039828               95.586652
# Figueroa High School           80.739234               73.363852
# Ford High School               79.299014               73.804308
# Griffin High School            97.138965               95.265668
# Hernandez High School          80.862999               73.807983
# Holden High School             96.252927               94.379391
# Huang High School              81.316421               73.500171
# Johnson High School            81.222432               73.639992
# Pena High School               95.945946               95.270270
# Rodriguez High School          80.220055               73.293323
# Shelton High School            95.854628               94.860875
# Thomas High School             97.308869               95.290520
# Wilson High School             96.539641               95.203679
# Wright High School             96.611111               94.972222

# %%
schoolsSummary_df.sort_values("% Overall Passing Rate", ascending=False).head()
# Out:
#                     School Type Total Students Total School Budget  \
# Cabrera High School   [Charter]          1,858       $1,081,356.00
# Thomas High School    [Charter]          1,635       $1,043,130.00
# Pena High School      [Charter]            962         $585,858.00
# Griffin High School   [Charter]          1,468         $917,500.00
# Wilson High School    [Charter]          2,283       $1,319,574.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Pena High School               $609.00           83.839917
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# Thomas High School               83.848930       93.272171          97.308869
# Pena High School                 84.044699       94.594595          95.945946
# Griffin High School              83.816757       93.392371          97.138965
# Wilson High School               83.989488       93.867718          96.539641
#
#                      % Overall Passing Rate
# Cabrera High School               95.586652
# Thomas High School                95.290520
# Pena High School                  95.270270
# Griffin High School               95.265668
# Wilson High School                95.203679

# %%
schoolsSummary_df.sort_values("% Overall Passing Rate", ascending=True).head()
# Out:
#                       School Type Total Students Total School Budget  \
# Rodriguez High School  [District]          3,999       $2,547,363.00
# Figueroa High School   [District]          2,949       $1,884,411.00
# Huang High School      [District]          2,917       $1,910,635.00
# Johnson High School    [District]          4,761       $3,094,650.00
# Ford High School       [District]          2,739       $1,763,916.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Ford High School                 $644.00           77.102592
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# Figueroa High School               81.158020       65.988471
# Huang High School                  81.182722       65.683922
# Johnson High School                80.966394       66.057551
# Ford High School                   80.746258       68.309602
#
#                        % Passing Reading  % Overall Passing Rate
# Rodriguez High School          80.220055               73.293323
# Figueroa High School           80.739234               73.363852
# Huang High School              81.316421               73.500171
# Johnson High School            81.222432               73.639992
# Ford High School               79.299014               73.804308
